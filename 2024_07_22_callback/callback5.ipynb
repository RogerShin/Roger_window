# %%
import data
import pandas as pd

content = data.get_snaOfArea(area='士林區')
df = pd.DataFrame(content)
df.columns = ['站點名稱', '總數', '可借', '可還', '日期', '狀態']
df.to_dict('records')
# Out:
# [{'站點名稱': '劍潭抽水站',
#   '總數': 17,
#   '可借': 3,
#   '可還': 14,
#   '日期': Timestamp('2024-07-05 15:10:32'),
#   '狀態': True},
#  {'站點名稱': '通河東街大南路口',
#   '總數': 15,
#   '可借': 4,
#   '可還': 9,
#   '日期': Timestamp('2024-07-05 14:35:21'),
#   '狀態': True},
#  {'站點名稱': '福港街停車場',
#   '總數': 22,
#   '可借': 1,
#   '可還': 21,
#   '日期': Timestamp('2024-07-05 15:21:20'),
#   '狀態': True},
#  {'站點名稱': '百齡國小',
#   '總數': 50,
#   '可借': 0,
#   '可還': 50,
#   '日期': Timestamp('2024-07-05 15:12:14'),
#   '狀態': True},
#  {'站點名稱': '雨聲街165巷口',
#   '總數': 25,
#   '可借': 7,
#   '可還': 18,
#   '日期': Timestamp('2024-07-05 15:19:19'),
#   '狀態': True},
#  {'站點名稱': '天和公園',
#   '總數': 16,
#   '可借': 2,
#   '可還': 14,
#   '日期': Timestamp('2024-07-05 15:21:20'),
#   '狀態': True},
#  {'站點名稱': '中山天母路口',
#   '總數': 29,
#   '可借': 11,
#   '可還': 18,
#   '日期': Timestamp('2024-07-05 15:22:20'),
#   '狀態': True},
#  {'站點名稱': '天母運動公園',
#   '總數': 50,
#   '可借': 26,
#   '可還': 23,
#   '日期': Timestamp('2024-07-05 15:21:20'),
#   '狀態': True},
# ...
